# %%
from trading_tools import StockScreener
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
spy = StockScreener()

# %%
spy.get_stock_symbols(index="SPX")
# Out:
# ['AAPL',
#  'MSFT',
#  'GOOGL',
#  'GOOG',
#  'AMZN',
#  'TSLA',
#  'FB',
#  'BRK.B',
#  'NVDA',
#  'JPM',
#  'V',
#  'UNH',
#  'JNJ',
#  'WMT',
#  'HD',
#  'BAC',
#  'PG',
#  'MA',
#  'PFE',
#  'XOM',
#  'DIS',
#  'KO',
#  'CSCO',
#  'CVX',
#  'AVGO',
#  'ADBE',
#  'PEP',
#  'TMO',
#  'LLY',
#  'ABBV',
#  'ACN',
#  'CMCSA',
#  'NKE',
#  'ORCL',
#  'NFLX',
#  'WFC',
#  'CRM',
#  'ABT',
#  'COST',
#  'INTC',
#  'VZ',
#  'QCOM',
#  'PYPL',
#  'DHR',
#  'MRK',
#  'MCD',
#  'T',
#  'UPS',
#  'MS',
#  'SCHW',
#  'TXN',
#  'LIN',
#  'LOW',
#  'NEE',
#  'AMD',
#  'UNP',
#  'PM',
#  'INTU',
#  'HON',
#  'MDT',
#  'BMY',
#  'AMAT',
#  'CVS',
#  'RTX',
#  'TMUS',
#  'BA',
#  'C',
#  'AMGN',
#  'BLK',
#  'AXP',
#  'GS',
#  'CAT',
#  'IBM',
#  'SBUX',
#  'EL',
#  'PLD',
#  'DE',
#  'AMT',
#  'COP',
#  'GE',
#  'CHTR',
#  'ISRG',
#  'ANTM',
#  'MU',
#  'TGT',
#  'NOW',
#  'SPGI',
#  'MMM',
#  'LMT',
#  'BKNG',
#  'SYK',
#  'F',
#  'LRCX',
#  'ZTS',
#  'ADP',
#  'PNC',
#  'MDLZ',
#  'USB',
#  'MO',
#  'GILD',
#  'ADI',
#  'GM',
#  'TFC',
#  'TJX',
#  'CB',
#  'MRNA',
#  'SHW',
#  'MMC',
#  'CSX',
#  'CCI',
#  'CI',
#  'DUK',
#  'CME',
#  'HCA',
#  'ITW',
#  'BDX',
#  'EW',
#  'SO',
#  'FIS',
#  'ICE',
#  'FISV',
#  'NSC',
#  'CL',
#  'FDX',
#  'ETN',
#  'EQIX',
#  'COF',
#  'MCO',
#  'REGN',
#  'WM',
#  'KLAC',
#  'APD',
#  'FCX',
#  'D',
#  'PSA',
#  'PGR',
#  'NOC',
#  'BSX',
#  'ECL',
#  'ILMN',
#  'EOG',
#  'AON',
#  'NXPI',
#  'GD',
#  'VRTX',
#  'EMR',
#  'MET',
#  'ADSK',
#  'EXC',
#  'JCI',
#  'SPG',
#  'MAR',
#  'BK',
#  'TEL',
#  'SLB',
#  'PXD',
#  'AIG',
#  'HUM',
#  'FTNT',
#  'DG',
#  'SNPS',
#  'ATVI',
#  'APH',
#  'NEM',
#  'MNST',
#  'INFO',
#  'XLNX',
#  'KMB',
#  'IQV',
#  'ROP',
#  'STZ',
#  'ORLY',
#  'WBA',
#  'MCHP',
#  'CNC',
#  'KHC',
#  'AEP',
#  'CTSH',
#  'MPC',
#  'PAYX',
#  'CDNS',
#  'IDXX',
#  'DLR',
#  'DOW',
#  'CARR',
#  'DXCM',
#  'PRU',
#  'SRE',
#  'TT',
#  'LHX',
#  'A',
#  'GPN',
#  'DD',
#  'MSCI',
#  'BAX',
#  'CMG',
#  'AZO',
#  'MSI',
#  'APTV',
#  'AFL',
#  'GIS',
#  'PH',
#  'CTAS',
#  'HPQ',
#  'ALGN',
#  'RSG',
#  'HLT',
#  'SIVB',
#  'SYY',
#  'O',
#  'HSY',
#  'TRV',
#  'ANET',
#  'KMI',
#  'ADM',
#  'PPG',
#  'EBAY',
#  'TROW',
#  'MCK',
#  'PSX',
#  'WELL',
#  'ROK',
#  'YUM',
#  'STT',
#  'DFS',
#  'XEL',
#  'ODFL',
#  'IFF',
#  'RMD',
#  'EA',
#  'AMP',
#  'ROST',
#  'SBAC',
#  'KR',
#  'OTIS',
#  'ALL',
#  'DHI',
#  'TDG',
#  'CTVA',
#  'WMB',
#  'AVB',
#  'CBRE',
#  'MTD',
#  'DVN',
#  'FAST',
#  'MTCH',
#  'BIIB',
#  'VLO',
#  'FRC',
#  'EQR',
#  'KEYS',
#  'FITB',
#  'LYB',
#  'CMI',
#  'ARE',
#  'TSN',
#  'PCAR',
#  'PEG',
#  'LEN',
#  'AME',
#  'AJG',
#  'LVS',
#  'OXY',
#  'CPRT',
#  'VRSK',
#  'GLW',
#  'NUE',
#  'SWK',
#  'WY',
#  'NDAQ',
#  'TWTR',
#  'BF.B',
#  'EFX',
#  'ANSS',
#  'EPAM',
#  'WEC',
#  'ES',
#  'AWK',
#  'DLTR',
#  'ED',
#  'BLL',
#  'HES',
#  'ZBRA',
#  'BKR',
#  'VFC',
#  'WST',
#  'ABC',
#  'OKE',
#  'EXPE',
#  'EXR',
#  'NTRS',
#  'ALB',
#  'CERN',
#  'LUV',
#  'ZBH',
#  'LH',
#  'SYF',
#  'HRL',
#  'TER',
#  'CDW',
#  'TSCO',
#  'FTV',
#  'GWW',
#  'DAL',
#  'VMC',
#  'DOV',
#  'HAL',
#  'SWKS',
#  'MKC',
#  'VRSN',
#  'CHD',
#  'CCL',
#  'MAA',
#  'MLM',
#  'GRMN',
#  'LYV',
#  'HBAN',
#  'KEY',
#  'BBY',
#  'STX',
#  'HIG',
#  'URI',
#  'EIX',
#  'IR',
#  'RF',
#  'CFG',
#  'MTB',
#  'IT',
#  'FE',
#  'VIAC',
#  'STE',
#  'FANG',
#  'DRE',
#  'DTE',
#  'K',
#  'AEE',
#  'CLX',
#  'ESS',
#  'PKI',
#  'PPL',
#  'HPE',
#  'RJF',
#  'ETR',
#  'FOX',
#  'FOXA',
#  'VTR',
#  'NTAP',
#  'MGM',
#  'JBHT',
#  'ETSY',
#  'RCL',
#  'WDC',
#  'SBNY',
#  'EXPD',
#  'PAYC',
#  'WAT',
#  'COO',
#  'ULTA',
#  'PFG',
#  'XYL',
#  'POOL',
#  'MPWR',
#  'NVR',
#  'FLT',
#  'GPC',
#  'ENPH',
#  'GNRC',
#  'BXP',
#  'TDY',
#  'TYL',
#  'PEAK',
#  'TRMB',
#  'CINF',
#  'DISH',
#  'BRO',
#  'IP',
#  'BIO',
#  'BR',
#  'CE',
#  'AMCR',
#  'CTLT',
#  'KMX',
#  'CMS',
#  'DRI',
#  'AKAM',
#  'UDR',
#  'VTRS',
#  'CZR',
#  'CTRA',
#  'WAB',
#  'CRL',
#  'BEN',
#  'DGX',
#  'HOLX',
#  'TTWO',
#  'AVY',
#  'J',
#  'CNP',
#  'DPZ',
#  'EMN',
#  'IEX',
#  'TXT',
#  'OMC',
#  'LKQ',
#  'MAS',
#  'CAG',
#  'MOS',
#  'QRVO',
#  'INCY',
#  'FDS',
#  'ROL',
#  'KIM',
#  'L',
#  'TECH',
#  'SJM',
#  'NLOK',
#  'AES',
#  'TFX',
#  'UAL',
#  'PWR',
#  'WRB',
#  'LNT',
#  'EVRG',
#  'AAP',
#  'MRO',
#  'IPG',
#  'CAH',
#  'HWM',
#  'DISCA',
#  'DISCK',
#  'PHM',
#  'FFIV',
#  'BBWI',
#  'FMC',
#  'CF',
#  'CHRW',
#  'HAS',
#  'ATO',
#  'FBHS',
#  'CPB',
#  'MKTX',
#  'ABMD',
#  'SEDG',
#  'PTC',
#  'NWS',
#  'NWSA',
#  'WHR',
#  'REG',
#  'IRM',
#  'LNC',
#  'CMA',
#  'LDOS',
#  'AOS',
#  'PKG',
#  'HST',
#  'RHI',
#  'CDAY',
#  'CBOE',
#  'LUMN',
#  'JKHY',
#  'WRK',
#  'AAL',
#  'BWA',
#  'APA',
#  'MHK',
#  'CTXS',
#  'DVA',
#  'XRAY',
#  'SNA',
#  'IVZ',
#  'RE',
#  'JNPR',
#  'ALLE',
#  'NI',
#  'PNR',
#  'TAP',
#  'ZION',
#  'TPR',
#  'FRT',
#  'HSIC',
#  'UHS',
#  'WYNN',
#  'GL',
#  'NWL',
#  'SEE',
#  'LW',
#  'NRG',
#  'NCLH',
#  'PBCT',
#  'VNO',
#  'AIZ',
#  'IPGP',
#  'DXC',
#  'RL',
#  'OGN',
#  'UA',
#  'UAA',
#  'PNW',
#  'HII',
#  'PENN',
#  'NLSN',
#  'PVH',
#  'ALK',
#  'GPS']

# %%
len(spy.symbol_list)
# Out:
# 504

# %%
spy.get_heavy_volume_stocks()
# Out:
# [*********************100%%**********************]  504 of 504 completed
# 24 Failed downloads:
# ['CTXS', 'INFO', 'CERN', 'PBCT', 'FISV', 'XLNX', 'VIAC', 'ANTM', 'TWTR', 'NLOK', 'RE', 'NLSN', 'DRE', 'BRK.B', 'SIVB', 'FBHS', 'FRC', 'BLL', 'DISCA', 'DISCK', 'PKI', 'FB']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['ABMD', 'BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-08-17 22:43:53.666725 -> 2023-09-16 22:43:53.666742)')
# ['LNC',
#  'TFX',
#  'SYK',
#  'DTE',
#  'INTU',
#  'LDOS',
#  'RTX',
#  'NI',
#  'SHW',
#  'SO',
#  'WMT',
#  'CDNS',
#  'SNPS',
#  'KO',
#  'ALLE',
#  'HD',
#  'MMM',
#  'CAG',
#  'MOS',
#  'NWSA',
#  'ABC',
#  'TRMB',
#  'DVN',
#  'HON',
#  'HES',
#  'EVRG',
#  'LIN',
#  'EA',
#  'EMR',
#  'HRL',
#  'WRB',
#  'VTRS',
#  'D',
#  'PTC',
#  'WYNN',
#  'AMZN',
#  'VRSN',
#  'TER',
#  'AXP',
#  'CAT',
#  'CHRW',
#  'MCO',
#  'MKC',
#  'MO',
#  'PM',
#  'UNH',
#  'MAS',
#  'EIX',
#  'HWM',
#  'BXP',
#  'FTNT',
#  'BSX',
#  'PSA',
#  'HAS',
#  'AIG',
#  'NXPI',
#  'VMC',
#  'MHK',
#  'OTIS',
#  'CMS',
#  'HOLX',
#  'SCHW',
#  'GE',
#  'CRM',
#  'PYPL',
#  'PLD',
#  'TFC',
#  'CF',
#  'TRV',
#  'OMC',
#  'ZION',
#  'AMAT',
#  'MSFT',
#  'A',
#  'TDG',
#  'GILD',
#  'ATVI',
#  'K',
#  'KHC',
#  'ILMN',
#  'PEP',
#  'YUM',
#  'WM',
#  'COF',
#  'VZ',
#  'J',
#  'JPM',
#  'GPN',
#  'EXPE',
#  'TMUS',
#  'CL',
#  'CRL',
#  'PENN',
#  'MSI',
#  'HLT',
#  'JBHT',
#  'LYB',
#  'JKHY',
#  'PNW',
#  'SPG',
#  'GPS',
#  'AMP',
#  'SPGI',
#  'MS',
#  'STE',
#  'ACN',
#  'KR',
#  'UHS',
#  'HII',
#  'ECL',
#  'ABBV',
#  'ETN',
#  'WST',
#  'AVY',
#  'DHR',
#  'MMC',
#  'ITW',
#  'HPQ',
#  'USB',
#  'AMT',
#  'FANG',
#  'BKNG',
#  'IVZ',
#  'HIG',
#  'CSX',
#  'DOV',
#  'ORCL',
#  'PSX',
#  'LEN',
#  'DXCM',
#  'WAT',
#  'NEE',
#  'AKAM',
#  'SNA',
#  'LLY',
#  'IP',
#  'FFIV',
#  'HPE',
#  'KEYS',
#  'MCK',
#  'ZTS',
#  'SRE',
#  'MAR',
#  'TPR',
#  'EQR',
#  'INTC',
#  'FDS',
#  'O',
#  'EPAM',
#  'RF',
#  'ADBE',
#  'AOS',
#  'CAH',
#  'ADI',
#  'MCHP',
#  'FLT',
#  'STT',
#  'PEG',
#  'CBOE',
#  'COP',
#  'DISH',
#  'WELL',
#  'LMT',
#  'HAL',
#  'AEP',
#  'AMGN',
#  'GS',
#  'UNP',
#  'KMI',
#  'EL',
#  'KMX',
#  'MRNA',
#  'SBUX',
#  'CFG',
#  'BRO',
#  'F',
#  'PNC',
#  'KLAC',
#  'ISRG',
#  'GLW',
#  'NTAP',
#  'SWK',
#  'SYY',
#  'T',
#  'QRVO',
#  'CTAS',
#  'EXPD',
#  'CBRE',
#  'BMY',
#  'PFE',
#  'MCD',
#  'BWA',
#  'RCL',
#  'VRTX',
#  'RJF',
#  'NVR',
#  'MTB',
#  'IPGP',
#  'WHR',
#  'PAYX',
#  'CTRA',
#  'NWL',
#  'AZO',
#  'MSCI',
#  'IRM',
#  'WEC',
#  'NUE',
#  'PWR',
#  'L',
#  'PG',
#  'CMA',
#  'MLM',
#  'ES',
#  'AWK',
#  'CNP',
#  'ABT',
#  'EQIX',
#  'GIS',
#  'GOOG',
#  'MTD',
#  'WMB',
#  'WFC',
#  'BIO',
#  'IT',
#  'EXR',
#  'VRSK',
#  'BKR',
#  'GRMN',
#  'APA',
#  'MPWR',
#  'CTSH',
#  'IBM',
#  'IPG',
#  'OXY',
#  'VLO',
#  'UDR',
#  'PGR',
#  'AMCR',
#  'NEM',
#  'ALK',
#  'SEDG',
#  'BR',
#  'MDLZ',
#  'PFG',
#  'VNO',
#  'RHI',
#  'ALL',
#  'DVA',
#  'TMO',
#  'NOC',
#  'MKTX',
#  'CVX',
#  'TTWO',
#  'TROW',
#  'ROP',
#  'DPZ',
#  'MA',
#  'ADP',
#  'ROL',
#  'ANSS',
#  'SWKS',
#  'MET',
#  'MRO',
#  'IDXX',
#  'TYL',
#  'SJM',
#  'PPL',
#  'WY',
#  'FOX',
#  'AJG',
#  'ETSY',
#  'ODFL',
#  'AVGO',
#  'AME',
#  'XRAY',
#  'NOW',
#  'LOW',
#  'PKG',
#  'CSCO',
#  'BIIB',
#  'EFX',
#  'PPG',
#  'PRU',
#  'EBAY',
#  'SLB',
#  'CTVA',
#  'SBAC',
#  'NFLX',
#  'AFL',
#  'GL',
#  'GD',
#  'LNT',
#  'GOOGL',
#  'IQV',
#  'AIZ',
#  'DD',
#  'GM',
#  'POOL',
#  'ORLY',
#  'AAPL',
#  'DUK',
#  'SYF',
#  'WAB',
#  'BAC',
#  'CPRT',
#  'FAST',
#  'AES',
#  'CPB',
#  'DLR',
#  'ESS',
#  'V',
#  'DHI',
#  'XEL',
#  'TECH',
#  'TT',
#  'BDX',
#  'KEY',
#  'CMCSA',
#  'BLK',
#  'CINF',
#  'PCAR',
#  'COST',
#  'MGM',
#  'CHTR',
#  'FOXA',
#  'MDT',
#  'PAYC',
#  'CCI',
#  'DFS',
#  'TXT',
#  'HSY',
#  'PNR',
#  'OGN',
#  'CDW',
#  'ADM',
#  'FIS',
#  'APTV',
#  'PEAK',
#  'AON',
#  'MTCH',
#  'HST',
#  'PHM',
#  'STZ',
#  'OKE',
#  'CLX',
#  'EOG',
#  'MAA',
#  'EXC',
#  'LRCX',
#  'DOW',
#  'JNPR',
#  'LUMN',
#  'REGN',
#  'MNST',
#  'CTLT',
#  'XYL',
#  'APD',
#  'AVB',
#  'XOM',
#  'VTR',
#  'DXC',
#  'IFF',
#  'CB',
#  'TXN',
#  'HBAN',
#  'NWS',
#  'ED',
#  'CHD',
#  'BAX',
#  'MPC',
#  'ARE',
#  'ATO',
#  'FE',
#  'BK',
#  'LKQ',
#  'HCA']

# %%
len(spy.heavy_volume_stocks)
# Out:
# 376
